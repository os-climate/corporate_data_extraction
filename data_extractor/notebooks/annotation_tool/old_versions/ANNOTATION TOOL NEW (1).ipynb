# %% [markdown]
# ## ANNOTATION TOOL

# %%
import pandas as pd
import os
import glob
import numpy as np
import ipywidgets as widgets

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# #### KPI MAPPING DOWNLOAD

# %%
import os
import pathlib
from dotenv import load_dotenv
from src.data.s3_communication import S3FileType, S3Communication

# Load credentials?
dotenv_dir = os.environ.get("CREDENTIAL_DOTENV_DIR", os.environ.get("PWD", "/opt/app-root/src"))
dotenv_path = pathlib.Path(dotenv_dir) / "credentials.env"
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path=dotenv_path, override=True)

# Init s3 communication
s3c = S3Communication(
    s3_endpoint_url=os.getenv("S3_ENDPOINT"),
    aws_access_key_id=os.getenv("S3_ACCESS_KEY"),
    aws_secret_access_key=os.getenv("S3_SECRET_KEY"),
    s3_bucket=os.getenv("S3_BUCKET"),
)

# Read kpi mapping csv from s3
kpi_mapping_df = s3c.download_df_from_s3(
    "corpdata/ESG/kpi_mapping",
    "kpi_mapping.csv",
    filetype=S3FileType.CSV,
    header=0,
)

# %% [markdown]
# Save kpi mapping to csv

# %%
kpi_mapping_df.to_csv("kpi_mapping.csv")

# %% [markdown]
# Print kpi mapping

# %%
kpi_mapping_df.head(30)
# Out:
#     kpi_id  \
# 0      0.0
# 1      1.0
# 2      2.0
# 3      2.1
# 4      2.2
# 5      3.0
# 6      3.1
# 7      3.2
# 8      3.3
# 9      4.0
# 10     4.1
# 11     4.2
# 12     5.0
# 13     5.1
# 14     5.2
# 15     6.0
# 16     7.0
# 17     8.0
# 18     9.0
# 19    10.0
# 20    11.0
# 21    12.0
# 22    13.0
# 23    14.0
#
#                                                                                                              question  \
# 0                                                                                           What is the company name?
# 1                                         In which year was the annual report or the sustainability report published?
# 2                                              What is the total volume of proven and probable hydrocarbons reserves?
# 3                                                       What is the volume of estimated proven hydrocarbons reserves?
# 4                                                     What is the volume of estimated probable hydrocarbons reserves?
# 5                                                                What is the total volume of hydrocarbons production?
# 6                                                            What is the total volume of crude oil liquid production?
# 7                                                          What is the total volume of natural gas liquid production?
# 8                                                                 What is the total volume of natural gas production?
# 9                                                                      What is the annual total production from coal?
# 10                                                     What is the annual total production from lignite (brown coal)?
# 11                                                                What is the annual total production from hard coal?
# 12                                                                    What is the total installed capacity from coal?
# 13                                                    What is the total installed capacity from lignite (brown coal)?
# 14                                                               What is the total installed capacity from hard coal?
# 15                    What is the total amount of direct greenhouse gases emissions referred to as scope 1 emissions?
# 16           What is the total amount of energy indirect greenhouse gases emissions referred to as scope 2 emissions?
# 17  What is the total amount of upstream energy indirect greenhouse gases emissions referred to as scope 3 emissions?
# 18                                                             What is the base year for carbon reduction commitment?
# 19                                                                What is the climate commitment scenario considered?
# 20                                                                    What is the target year for climate commitment?
# 21                                                                 What is the target carbon reduction in percentage?
# 22                                              What is the total amount of scope 1 and 2 greenhouse gases emissions?
# 23                               What is the total amount of scope 1, scope 2 and scope 3 greenhouse gases emissions?
#
#        sectors  add_year kpi_category  Unnamed: 5  Unnamed: 6
# 0   OG, CM, CU     False         TEXT         NaN         NaN
# 1   OG, CM, CU     False         TEXT         NaN         NaN
# 2           OG      True  TEXT, TABLE         NaN         NaN
# 3           OG      True  TEXT, TABLE         NaN         NaN
# 4           OG      True  TEXT, TABLE         NaN         NaN
# 5           OG      True  TEXT, TABLE         NaN         NaN
# 6           OG      True  TEXT, TABLE         NaN         NaN
# 7           OG      True  TEXT, TABLE         NaN         NaN
# 8           OG      True  TEXT, TABLE         NaN         NaN
# 9           CU      True  TEXT, TABLE         NaN         NaN
# 10          CU      True  TEXT, TABLE         NaN         NaN
# 11          CU      True  TEXT, TABLE         NaN         NaN
# 12          CU      True  TEXT, TABLE         NaN         NaN
# 13          CU      True  TEXT, TABLE         NaN         NaN
# 14          CU      True  TEXT, TABLE         NaN         NaN
# 15      CU, OG      True  TEXT, TABLE         NaN         NaN
# 16      CU, OG      True  TEXT, TABLE         NaN         NaN
# 17      CU, OG      True  TEXT, TABLE         NaN         NaN
# 18  OG, CM, CU     False  TEXT, TABLE         NaN         NaN
# 19  OG, CM, CU      True         TEXT         NaN         NaN
# 20  OG, CM, CU     False         TEXT         NaN         NaN
# 21  OG, CM, CU      True         TEXT         NaN         NaN
# 22          CU      True  TEXT, TABLE         NaN         NaN
# 23          OG      True  TEXT, TABLE         NaN         NaN

# %% [markdown]
# ### 1. Settings

# %% [markdown]
# Please change the settings to the needed ones.

# %%
annotations_path = "/opt/app-root/src/corporate_data_pipeline/NLP_ANNOTATION_TOOL"
output_path = "/opt/app-root/src/corporate_data_pipeline/NLP_ANNOTATION_TOOL/output"
annotator = "Max"
all_kpi = list(kpi_mapping_df["kpi_id"])
# kpi_of_interest = all_kpi
kpi_of_interest = [0, 1, 6, 7, 8, 9, 10, 11, 12, 13, 14]

# %%
for idx in range(len(all_kpi)):
    if all_kpi[idx].is_integer():
        all_kpi[idx] = int(all_kpi[idx])
print(f"All KPI's are " + ", ".join([str(x) for x in all_kpi]) + ".")
print(f"KPI's of interest are " + ", ".join([str(x) for x in kpi_of_interest]) + ".")
# Out:
# All KPI's are 0, 1, 2, 2.1, 2.2, 3, 3.1, 3.2, 3.3, 4, 4.1, 4.2, 5, 5.1, 5.2, 6, 7, 8, 9, 10, 11, 12, 13, 14.
# KPI's of interest are 0, 1, 6, 7, 8, 9, 10, 11, 12, 13, 14.

# %% [markdown]
# ### 2. Preloading

# %% [markdown]
# loading packages and the existing annotations (just execute)

# %%
df_annotations = pd.read_excel(annotations_path + "/annotations.xlsx")
df_out = df_annotations.copy()

# %% [markdown]
# ### 3. Annotations overview

# %% [markdown]
# The following gives an overview of the existing predictions and which file needs a further investigation (just execute)

# %%
outputs = glob.glob(output_path + "/*")
outputs = [x.rsplit("/", 1)[1] for x in outputs]
if len(outputs) > 1:
    print(f"There are {len(outputs)} output files in the output folder:" + "\n" + "\n".join([str(x) for x in outputs]))
elif len(outputs) == 1:
    print(f"There is one output file in the output folder.")
else:
    print(f"There are no new files in the output folder.")


for output in outputs:
    print("\n Next file considered: " + output)
    df_output = pd.read_csv(output_path + "/" + output)
    pdf_name = df_output["pdf_name"].values[0]
    df_annotations_temp = df_annotations[df_annotations["source_file"] == pdf_name]
    kpis_contained = [x for x in df_annotations_temp["kpi_id"].values if x in kpi_of_interest]
    if len(kpis_contained) > 1:
        print(
            'For pdf with name "'
            + pdf_name
            + '" in file '
            + output
            + " we have already annotations for the kpi's "
            + ", ".join([str(x) for x in kpis_contained])
            + "."
        )
    elif len(kpis_contained) == 1:
        print(
            'For pdf with name "'
            + pdf_name
            + "\ in file "
            + output
            + " we have already an annotation for the kpi "
            + ",".join([str(x) for x in kpis_contained])
            + "."
        )
    else:
        print('For pdf with name "' + pdf_name + "\" we have no annotations yet for the kpi's under investigation.")
    if kpis_contained == kpi_of_interest:
        print("DONE: All kpi's of interest have been annotated for this file.")
    else:
        print("TODO: There are open annotations for that file.")
# Out:
# There are 14 output files in the output folder:
# 408712981_ENEOS Hldgs Inc_2021-01-26_predictions_kpi.csv
# 381772374_Valero Energy Corp_2019-12-31_predictions_kpi.csv
# 389905632_Engie_2019-12-31_predictions_kpi.csv
# 386749585_Hyundai Motor Co_2020-08-06_predictions_kpi.csv
# 392903246_Nissan Motor Co_2020-03-31_predictions_kpi.csv
# 405604636_Exxon Mobil Corp_2021-01-05_predictions_kpi.csv
# 286359582_Mitsubishi Estate_2018-03-31_predictions_kpi.csv
# 231699798_Volkswagen AG_2017-12-31_predictions_kpi.csv
# test_predictions_kpi.csv
# 371393592_Royal Dutch Shell_2019-12-31_predictions_kpi.csv
# 388265206_General Motors Co_2019-12-31_predictions_kpi.csv
# 366497869_Imperial Oil Ltd_2018-12-31_predictions_kpi.csv
# test2_predictions_kpi.csv
# 345132457_FDG Electric Vehic_2019-03-31_predictions_kpi.csv
#
#  Next file considered: 408712981_ENEOS Hldgs Inc_2021-01-26_predictions_kpi.csv
# For pdf with name "408712981_ENEOS Hldgs Inc_2021-01-26" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 381772374_Valero Energy Corp_2019-12-31_predictions_kpi.csv
# For pdf with name "381772374_Valero Energy Corp_2019-12-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 389905632_Engie_2019-12-31_predictions_kpi.csv
# For pdf with name "389905632_Engie_2019-12-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 386749585_Hyundai Motor Co_2020-08-06_predictions_kpi.csv
# For pdf with name "386749585_Hyundai Motor Co_2020-08-06" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 392903246_Nissan Motor Co_2020-03-31_predictions_kpi.csv
# For pdf with name "392903246_Nissan Motor Co_2020-03-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 405604636_Exxon Mobil Corp_2021-01-05_predictions_kpi.csv
# For pdf with name "405604636_Exxon Mobil Corp_2021-01-05" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 286359582_Mitsubishi Estate_2018-03-31_predictions_kpi.csv
# For pdf with name "286359582_Mitsubishi Estate_2018-03-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 231699798_Volkswagen AG_2017-12-31_predictions_kpi.csv
# For pdf with name "231699798_Volkswagen AG_2017-12-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: test_predictions_kpi.csv
# For pdf with name "test.pdf" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 371393592_Royal Dutch Shell_2019-12-31_predictions_kpi.csv
# For pdf with name "371393592_Royal Dutch Shell_2019-12-31" in file 371393592_Royal Dutch Shell_2019-12-31_predictions_kpi.csv we have already annotations for the kpi's 0, 1, 6, 7, 8, 9, 10, 11, 12, 13, 14.
# DONE: All kpi's of interest have been annotated for this file.
#
#  Next file considered: 388265206_General Motors Co_2019-12-31_predictions_kpi.csv
# For pdf with name "388265206_General Motors Co_2019-12-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 366497869_Imperial Oil Ltd_2018-12-31_predictions_kpi.csv
# For pdf with name "366497869_Imperial Oil Ltd_2018-12-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: test2_predictions_kpi.csv
# For pdf with name "test2.pdf" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.
#
#  Next file considered: 345132457_FDG Electric Vehic_2019-03-31_predictions_kpi.csv
# For pdf with name "345132457_FDG Electric Vehic_2019-03-31" we have no annotations yet for the kpi's under investigation.
# TODO: There are open annotations for that file.

# %% [markdown]
# ### 4. Check new annotations

# %% [markdown]
# Please set the file you want to investigate.

# %%
output_file = "286359582_Mitsubishi Estate_2018-03-31_predictions_kpi.csv"

# %% [markdown]
# List of open tasks (just execute)

# %%
df_output = pd.read_csv(output_path + "/" + output_file)
pdf_name = df_output["pdf_name"].values[0]
df_annotations_temp = df_annotations[df_annotations["source_file"] == pdf_name]
kpis_contained = [x for x in df_annotations_temp["kpi_id"].values if x in kpi_of_interest]
open_kpis = [x for x in kpi_of_interest if x not in kpis_contained]
if len(open_kpis) > 1:
    print("The open kpi's are " + ", ".join([str(x) for x in open_kpis]) + ".")
elif len(open_kpis) == 1:
    print("The open kpi is " + ", ".join([str(x) for x in open_kpis]) + ".")
else:
    print("There are no open kpi's.")
# Out:
# The open kpi's are 0, 1, 6, 7, 8, 9, 10, 11, 12, 13, 14.

# %% [markdown]
# ### 4.1 Detailed investigation
# Please set the kpi you want to investigate.

# %%
kpi_to_investigate = 7
kpi = kpi_mapping_df.loc[kpi_mapping_df["kpi_id"] == kpi_to_investigate, "question"].values[0]

# %% [markdown]
# Get the outcome of the machine (just execute)

# %%
def dropdown_eventhandler(change):
    output.clear_output()
    with output:
        print("id_correct_answer: " + str(dropdown.value[1]))
        print("correct paragraph: " + str(toggle_paragraph.value))


# Check specific KPIs
df_output = pd.read_csv(output_path + "/" + output_file)
df_output = df_output.drop(columns="Unnamed: 0")
df_output_check = df_output[df_output["kpi"] == kpi]


index_list = df_output_check.index.values
select_list = []
for i, x in enumerate(index_list):
    select_list = select_list + [(i + 1, [i + 1, x])]
select_list = select_list + [("no correct answer", [-1, -1])]

output = widgets.Output()
dropdown = widgets.Dropdown(description="Choose rank:", options=select_list, value=None)
toggle_paragraph = widgets.ToggleButtons(
    options=[("Correct", 1), ("Incorrect", -1)],
    description="Paragraph:",
    disabled=False,
    button_style="warning",  # 'success', 'info', 'warning', 'danger' or ''
    tooltips=["Description of slow", "Description of regular", "Description of fast"],
    #     icons=['check'] * 3
)
dropdown.observe(dropdown_eventhandler, names="value")
toggle_paragraph.observe(dropdown_eventhandler, names="value")

display(df_output_check.head(4))
display(dropdown)
display(toggle_paragraph)
display(output)
# Out:
#                                   pdf_name  \
# 33  286359582_Mitsubishi Estate_2018-03-31
# 34  286359582_Mitsubishi Estate_2018-03-31
# 35  286359582_Mitsubishi Estate_2018-03-31
# 36  286359582_Mitsubishi Estate_2018-03-31
#
#                                                                                                          kpi  \
# 33  What is the total amount of energy indirect greenhouse gases emissions referred to as scope 2 emissions?
# 34  What is the total amount of energy indirect greenhouse gases emissions referred to as scope 2 emissions?
# 35  What is the total amount of energy indirect greenhouse gases emissions referred to as scope 2 emissions?
# 36  What is the total amount of energy indirect greenhouse gases emissions referred to as scope 2 emissions?
#
#     kpi_id            answer  page  \
# 33     NaN         no_answer   NaN
# 34     NaN               150  29.0
# 35     NaN                 .  29.0
# 36     NaN  529,000 t a year  10.0
#
#                                                                                                      paragraph  \
# 33                                                                                                         NaN
# 34                                                           Emissions per unit of floor space (kg-CO2/m2) 150
# 35                                       Fuel oil 0.0% City gas 0.9% Heat (district heating and cooling) 23.6%
# 36  About 272,000 kl/ About 529,000 t a year 44,967 t/About 5,648,000 m3 a year 9/20/22 buildings and projects
#
#    source      score  no_ans_score  no_answer_score_plus_boost
# 33   Text   2.655437           NaN                         NaN
# 34   Text  -3.332447     17.333275                    2.333275
# 35   Text  -8.171566     17.655437                    2.655437
# 36   Text -12.567283     17.399271                    2.399271
# Dropdown(description='Choose rank:', options=((1, [1, 33]), (2, [2, 34]), (3, [3, 35]), (4, [4, 36]), ('no cor…
# ToggleButtons(button_style='warning', description='Paragraph:', options=(('Correct', 1), ('Incorrect', -1)), t…
# Output()

# %% [markdown]
# ### 4.2 Set answer

# %% [markdown]
# Define the id where one can find the correct paragraph and/or the answer. In case an optimal paragraph and/or answer does not exist, please specify it in the variables "correct_*".

# %%
# Campany related values
company = "Mitsubishi Estate"
year = 2018
sector = "Automotive"

# Only if paragraph is not contained
correct_paragraph = "Publication date: December 27, 2018"  #'Use of our refinery and natural gas products (Scope 3 Category 11) (million tonnes CO2 equivalent) [Q]'
correct_paragraph_page = 3
correct_paragraph_source = "TEXT"  # Either "TEXT" or "TABLE"

# Only if answer is not contained
correct_answer = "December 27, 2018"  # "576"

# %% [markdown]
# ### 4.3 Generate annotation outcome

# %% [markdown]
# After having set the correct annotations we can generate a new entry for the annotations file (just execute).

# %%
id_correct_paragraph = dropdown.value[1]
rank_correct_paragraph = dropdown.value[0]
id_correct_answer = dropdown.value[1]
rank_correct_answer = dropdown.value[0]

df_temp = df_annotations.head(0)
if toggle_paragraph.value == -1:
    paragraph = "[" + str(correct_paragraph) + "]"
    source_page = "[" + str(correct_paragraph_page) + "]"
    source = correct_paragraph_source
    paragraph_pred_rank = -1
    paragraph_pred_score = -100
else:
    paragraph = "[" + str(df_output_check.loc[id_correct_paragraph, "paragraph"]) + "]"
    source_page = "[" + str(df_output_check.loc[id_correct_paragraph, "page"]) + "]"
    source = df_output_check.loc[id_correct_paragraph, "source"]
    paragraph_pred_rank = rank_correct_paragraph
    paragraph_pred_score = 100


if id_correct_answer == -1:
    answer = correct_answer
    kpi_pred_rank = -1
    kpi_pred_score = -100
else:
    answer = df_output_check.loc[id_correct_paragraph, "answer"]
    kpi_pred_rank = rank_correct_answer
    kpi_pred_score = df_output_check.loc[df_output_check.index == id_correct_answer, "score"].values[0]

try:
    max_num = np.max(df_out["number"].values)
except ValueError:
    max_num = 1

new_data = [
    max_num + 1,
    company,
    df_output_check["pdf_name"].values[0],
    source_page,
    kpi_to_investigate,
    year,
    answer,
    source,
    paragraph,
    annotator,
    sector,
    "",
    paragraph_pred_rank,
    paragraph_pred_score,
    kpi_pred_rank,
    kpi_pred_score,
]
df_series = pd.Series(new_data, index=df_temp.columns)
df_temp = df_temp.append(df_series, ignore_index=True)
df_temp = df_temp.set_index([pd.Index([np.max(df_out.index) + 1])])
df_out = df_out.append(df_temp)
df_out.tail(4)
# Out:
#     number            company                             source_file  \
# 36      36  Mitsubishi Estate  286359582_Mitsubishi Estate_2018-03-31
# 37      37  Mitsubishi Estate  286359582_Mitsubishi Estate_2018-03-31
# 38      38  Mitsubishi Estate  286359582_Mitsubishi Estate_2018-03-31
# 39      39  Mitsubishi Estate  286359582_Mitsubishi Estate_2018-03-31
#
#    source_page  kpi_id  year            answer data_type  \
# 36      [10.0]      14  2018  529,000 t a year      Text
# 37      [29.0]      14  2018               150      Text
# 38      [29.0]      14  2018               150      Text
# 39         [3]      14  2018         no_answer      TEXT
#
#                                                                                              relevant_paragraphs  \
# 36  [About 272,000 kl/ About 529,000 t a year 44,967 t/About 5,648,000 m3 a year 9/20/22 buildings and projects]
# 37                                                           [Emissions per unit of floor space (kg-CO2/m2) 150]
# 38                                                           [Emissions per unit of floor space (kg-CO2/m2) 150]
# 39                                                                         [Publication date: December 27, 2018]
#
#    annotator      sector issue  paragraph_pred_rank  paragraph_pred_score  \
# 36       Max  Automotive                          3                   100
# 37       Max  Automotive                          2                   100
# 38       Max  Automotive                          2                   100
# 39       Max  Automotive                         -1                  -100
#
#     kpi_pred_rank  kpi_pred_score
# 36              3      -12.213235
# 37              2       -2.841095
# 38              2       -2.841095
# 39              1        2.258224

# %% [markdown]
# Check if there are still open kpi's. If yes start again at point 4.1. (just execute)

# %%
df_out_temp = df_out[df_out["source_file"] == pdf_name]
kpis_contained = [x for x in df_out_temp["kpi_id"].values if x in kpi_of_interest]
open_kpis = [x for x in kpi_of_interest if x not in kpis_contained]
if len(open_kpis) > 1:
    print("The open kpi's are " + ", ".join([str(x) for x in open_kpis]) + ".")
elif len(open_kpis) == 1:
    print("The open kpi is " + ", ".join([str(x) for x in open_kpis]) + ".")
else:
    print("There are no open kpi's.")
# Out:
# There are no open kpi's.

# %% [markdown]
# ### 4.4 Export outcome

# %%
df_out.to_excel(annotations_path + "/annotations.xlsx", index=False)

# %%
from datetime import datetime

construction_time = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
df_out.to_excel(annotations_path + "/annotations_" + construction_time + ".xlsx", index=False)

# %% [markdown]
# Note: After having exported the new annotations please start with the jupyter notebook from the beginning if you want to check the annotations of another file.

# %% [markdown]
# ## Notes:

# %% [markdown]
# * In output file year, company and sector are missing

# %% [markdown]
# Annotation Notes:
# * No kpi_ids in the inference output
# * No answer has no "no answer"-score
# * How to handle no answer in the annotations, if the answer is really not in the pdf? This is also an information, but probably can not be handled yet.
